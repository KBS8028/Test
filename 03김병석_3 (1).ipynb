# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('fivethirtyeight')
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
titanic = pd.read_csv('/content/drive/MyDrive/test/titanic.csv')

# %%
titanic
# Out:
#      PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 0              1         0       3  ...   7.2500   NaN         S
# 1              2         1       1  ...  71.2833   C85         C
# 2              3         1       3  ...   7.9250   NaN         S
# 3              4         1       1  ...  53.1000  C123         S
# 4              5         0       3  ...   8.0500   NaN         S
# ..           ...       ...     ...  ...      ...   ...       ...
# 886          887         0       2  ...  13.0000   NaN         S
# 887          888         1       1  ...  30.0000   B42         S
# 888          889         0       3  ...  23.4500   NaN         S
# 889          890         1       1  ...  30.0000  C148         C
# 890          891         0       3  ...   7.7500   NaN         Q
#
# [891 rows x 12 columns]

# %%
titanic.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# 생존자 확인

# %%
f,ax = plt.subplots(1,2,figsize=(20,8))
titanic['Survived'].value_counts().plot.pie(explode=[0,0.1], autopct='%1.1f%%',ax=ax[0],shadow=True)
ax[0].set_title('Survived')
ax[0].set_ylabel('')
#print(ax[1])
sns.countplot('Survived',data=titanic,ax=ax[1])
ax[1].set_title('Survived')
plt.show()

# %%
f,ax = plt.subplots(1,2,figsize=(20,8))
titanic['Sex'].value_counts().plot.pie(explode=[0,0.1], autopct='%1.1f%%',ax=ax[0],shadow=True)
ax[0].set_title('Sex')
ax[0].set_ylabel('')
#print(ax[1])
sns.countplot('Sex',data=titanic,ax=ax[1])
ax[1].set_title('Sex')
plt.show()

# %% [markdown]
# 성별로 생존자 확인

# %%
titanic.groupby(['Sex','Survived'])['Survived'].count()
# Out:
# Sex     Survived
# female  0            81
#         1           233
# male    0           468
#         1           109
# Name: Survived, dtype: int64

# %%
f,ax = plt.subplots(1,2,figsize=(15,8))
titanic[['Sex','Survived']].groupby(['Sex']).mean().plot.bar(ax=ax[0])
ax[0].set_title('Survived VS Sex')
sns.countplot('Sex',hue='Survived',data=titanic,ax=ax[1])
ax[1].set_title('Sex:Survived VS Dead')
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %% [markdown]
# 객실 별 생존자

# %%
f,ax = plt.subplots(1,2,figsize=(15,8))
titanic[['Sex','Survived','Pclass']].groupby(['Pclass']).mean([]).plot.bar(ax=ax[0])
ax[0].set_title('Pclass Survived')
sns.countplot('Pclass',hue='Survived',data=titanic,ax=ax[1])
ax[1].set_title('Pclass:Survived VS Dead')
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %% [markdown]
# 탑승 한곳 기준 생존자 및 사망자

# %%
f,ax = plt.subplots(1,2,figsize=(15,8))
titanic[['Sex','Survived','Embarked']].groupby(['Embarked']).mean([]).plot.bar(ax=ax[0])
ax[0].set_title('Embarked Survived')
sns.countplot('Embarked',hue='Survived',data=titanic,ax=ax[1])
ax[1].set_title('Embarked:Survived VS Dead')
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %% [markdown]
# 객실 등급별 생존자

# %%
pd.crosstab(titanic.Pclass,titanic.Survived,margins=True).style.background_gradient(cmap='summer_r')
# Out:
# <style  type="text/css" >
# #T_1e1ccd84_4b76_11ec_b86d_0242ac1c0002row0_col0,#T_1e1ccd84_4b76_11ec_b86d_0242ac1c0002row1_col1,#T_1e1ccd84_4b76_11ec_b86d_0242ac1c0002row1_col2{
#             background-color:  #ffff66;
#             color:  #000000;
#         }#T_1e1ccd84_4b76_11ec_b86d_0242ac1c0002row0_col1{
#             background-color:  #cee666;
#             color:  #000000;
#         }#T_1e1ccd84_4b76_11ec_b86d_0242ac1c0002row0_col2{
#             background-color:  #f4fa66;
#             color:  #000000;
#         }#T_1e1ccd84_4b76_11ec_b86d_0242ac1c0002row1_col0{
#             background-color:  #f6fa66;
#             color:  #000000;
#         }#T_1e1ccd84_4b76_11ec_b86d_0242ac1c0002row2_col0{
#             background-color:  #60b066;
#             color:  #000000;
#         }#T_1e1ccd84_4b76_11ec_b86d_0242ac1c0002row2_col1{
#             background-color:  #dfef66;
#             color:  #000000;
#         }#T_1e1ccd84_4b76_11ec_b86d_0242ac1c0002row2_col2{
#             background-color:  #90c866;
#             color:  #000000;
#         }#T_1e1ccd84_4b76_11ec_b86d_0242ac1c0002row3_col0,#T_1e1ccd84_4b76_11ec_b86d_0242ac1c0002row3_col1,#T_1e1ccd84_4b76_11ec_b86d_0242ac1c0002row3_col2{
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }</style><table id="T_1e1ccd84_4b76_11ec_b86d_0242ac1c0002" class="dataframe"><thead>    <tr>        <th class="index_name level0" >Survived</th>        <th class="col_heading level0 col0" >0</th>        <th class="col_heading level0 col1" >1</th>        <th class="col_heading level0 col2" >All</th>    </tr>    <tr>        <th class="index_name level0" >Pclass</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_1e1ccd84_4b76_11ec_b86d_0242ac1c0002level0_row0" class="row_heading level0 row0" >1</th>
#                         <td id="T_1e1ccd84_4b76_11ec_b86d_0242ac1c0002row0_col0" class="data row0 col0" >80</td>
#                         <td id="T_1e1ccd84_4b76_11ec_b86d_0242ac1c0002row0_col1" class="data row0 col1" >136</td>
#                         <td id="T_1e1ccd84_4b76_11ec_b86d_0242ac1c0002row0_col2" class="data row0 col2" >216</td>
#             </tr>
#             <tr>
#                         <th id="T_1e1ccd84_4b76_11ec_b86d_0242ac1c0002level0_row1" class="row_heading level0 row1" >2</th>
#                         <td id="T_1e1ccd84_4b76_11ec_b86d_0242ac1c0002row1_col0" class="data row1 col0" >97</td>
#                         <td id="T_1e1ccd84_4b76_11ec_b86d_0242ac1c0002row1_col1" class="data row1 col1" >87</td>
#                         <td id="T_1e1ccd84_4b76_11ec_b86d_0242ac1c0002row1_col2" class="data row1 col2" >184</td>
#             </tr>
#             <tr>
#                         <th id="T_1e1ccd84_4b76_11ec_b86d_0242ac1c0002level0_row2" class="row_heading level0 row2" >3</th>
#                         <td id="T_1e1ccd84_4b76_11ec_b86d_0242ac1c0002row2_col0" class="data row2 col0" >372</td>
#                         <td id="T_1e1ccd84_4b76_11ec_b86d_0242ac1c0002row2_col1" class="data row2 col1" >119</td>
#                         <td id="T_1e1ccd84_4b76_11ec_b86d_0242ac1c0002row2_col2" class="data row2 col2" >491</td>
#             </tr>
#             <tr>
#                         <th id="T_1e1ccd84_4b76_11ec_b86d_0242ac1c0002level0_row3" class="row_heading level0 row3" >All</th>
#                         <td id="T_1e1ccd84_4b76_11ec_b86d_0242ac1c0002row3_col0" class="data row3 col0" >549</td>
#                         <td id="T_1e1ccd84_4b76_11ec_b86d_0242ac1c0002row3_col1" class="data row3 col1" >342</td>
#                         <td id="T_1e1ccd84_4b76_11ec_b86d_0242ac1c0002row3_col2" class="data row3 col2" >891</td>
#             </tr>
#     </tbody></table>

# %%
f,ax = plt.subplots(1,2,figsize=(18,8))
titanic['Pclass'].value_counts().plot.bar(color=['#CD7F32','#FFDF00','#D3D3D3'],ax=ax[0])
ax[0].set_title('Number of Passengers By Pclass')
ax[0].set_ylabel('Count')
sns.countplot('Pclass',hue='Survived',data=titanic,ax=ax[1])
ax[1].set_title('Pclass:Survived vs Dead')
# Out:
# Text(0.5, 1.0, 'Pclass:Survived vs Dead')

# %% [markdown]
# 성별에다른 객실별 생존율

# %%
sns.factorplot('Sex', 'Survived', hue = 'Pclass', data= titanic)
plt.show()

# %% [markdown]
# 성별에따른 탑승지별 생존율

# %%
sns.factorplot('Sex', 'Survived', hue = 'Embarked', data= titanic)
plt.show()
